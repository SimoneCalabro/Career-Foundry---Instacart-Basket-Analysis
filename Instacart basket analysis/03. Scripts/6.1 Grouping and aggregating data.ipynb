# %% [markdown]
# # 6.1 Grouping and aggregating data
# ** **
# ## Table of contents:
#
# 1. Importing libraries <br>
# 2. Importing dataframe <br>
# 3. Grouping and aggregating data
#     - 3.1 Grouping data
#     - 3.2 Aggregating data
#     - 3.3 Creating a new column with aggregated data
# 4. Creating a flag from the new aggregated column
# ** **

# %% [markdown]
# # 1. Importing libraries
# ** **

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing dataframe
# ** **

# %%
# Creating a path variabile for the folder
path = r'C:\Users\Simone\Desktop\Career Foundry\Esercizi modulo 5\Instacart basket analysis'

# %%
# Importing dataframe with the derived columns from Prepared Data
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# Checking the head
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          1         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
#
#          price_label     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy      Least busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy           Most orders
# 2  Mid-range product      Least busy      Least busy        Average orders
# 3  Mid-range product      Least busy      Least busy           Most orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders

# %% [markdown]
# # 3. Grouping and aggregating data

# %% [markdown]
# ## 3.1 Grouping data

# %% [markdown]
# To test how to group data, we will create a subset called "df".

# %%
# Creating a subset with only 1 million rows
df = df_ords_prods_merged[:1000000]

# %%
# Checking the head
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
# 5    550135        1             7                   1
# 6   3108588        1             8                   1
# 7   2295261        1             9                   1
# 8   2550362        1            10                   4
# 9   2968173       15            15                   1
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
# 5                       9                    20.0         196
# 6                      14                    14.0         196
# 7                      16                     0.0         196
# 8                       8                    30.0         196
# 9                       9                     7.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          1         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
# 5                  1          1         Soda        77              7     9.0
# 6                  2          1         Soda        77              7     9.0
# 7                  4          1         Soda        77              7     9.0
# 8                  1          1         Soda        77              7     9.0
# 9                  2          0         Soda        77              7     9.0
#
#          price_label     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy      Least busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy           Most orders
# 2  Mid-range product      Least busy      Least busy        Average orders
# 3  Mid-range product      Least busy      Least busy           Most orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders
# 5  Mid-range product  Regularly busy     Busiest day           Most orders
# 6  Mid-range product  Regularly busy     Busiest day           Most orders
# 7  Mid-range product  Regularly busy     Busiest day           Most orders
# 8  Mid-range product      Least busy      Least busy        Average orders
# 9  Mid-range product  Regularly busy     Busiest day           Most orders

# %%
# Checking the shape
df.shape
# Out:
# (1000000, 17)

# %%
# Using groupby function
df.groupby('product_name')

# %% [markdown]
# Using the .groupby() function alone, it returns only some text.
# We need to use the function together with the .agg function to make an aggregation.

# %% [markdown]
# ## 3.2 Aggregating data

# %%
# Using together groupby and agg function
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                19.765396
# 7                18.575283
# 13               18.950838
# 14               20.460336
# 16               20.262396
# 17               12.646785
# 19               20.168036
# 20               18.808671

# %% [markdown]
# With this line of code, we are grouping the data by "department_id" and aggregating it by the mean of the "order_number" column.

# %% [markdown]
# Is it possible to use also the function .mean to aggregate by the mean (instead of the .agg function).

# %%
# Testing another method
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     19.765396
# 7     18.575283
# 13    18.950838
# 14    20.460336
# 16    20.262396
# 17    12.646785
# 19    20.168036
# 20    18.808671
# Name: order_number, dtype: float64

# %% [markdown]
# The result is the same.

# %% [markdown]
# Using the .agg function, is possible to perform multiple aggregations in the same line of code.

# %%
# Performing multiple aggregations in the same line of code
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                19.765396   2  99
# 7                18.575283   2  99
# 13               18.950838   2  99
# 14               20.460336   2  99
# 16               20.262396   2  99
# 17               12.646785   2  98
# 19               20.168036   2  99
# 20               18.808671   2  99

# %% [markdown]
# ## 3.3 Creating a new column with aggregated data

# %% [markdown]
# Now that we know how to group and aggregate data, we can use our knowledge to create, on the real dataframe, a new column containing aggregated data.

# %%
# Creating a new column containing the max order number, with the data grouped by user id
df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  \
# 0    2398795        1             2                   3
# 1     473747        1             3                   3
# 2    2254736        1             4                   4
# 3     431534        1             5                   4
# 4    3367565        1             6                   2
# 5     550135        1             7                   1
# 6    3108588        1             8                   1
# 7    2295261        1             9                   1
# 8    2550362        1            10                   4
# 9    2968173       15            15                   1
# 10   1870022       15            17                   2
# 11   1911383       15            18                   2
# 12   2715276       15            21                   1
# 13    487368       15            22                   1
# 14   2293453       19             2                   5
#
#     order_hour_of_creation  days_since_prior_order  product_id  \
# 0                        7                    15.0         196
# 1                       12                    21.0         196
# 2                        7                    29.0         196
# 3                       15                    28.0         196
# 4                        7                    19.0         196
# 5                        9                    20.0         196
# 6                       14                    14.0         196
# 7                       16                     0.0         196
# 8                        8                    30.0         196
# 9                        9                     7.0         196
# 10                      16                     8.0         196
# 11                      11                     7.0         196
# 12                       9                     7.0         196
# 13                      10                    14.0         196
# 14                      14                     6.0         196
#
#     add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                   1          1         Soda        77              7
# 1                   1          1         Soda        77              7
# 2                   1          1         Soda        77              7
# 3                   1          1         Soda        77              7
# 4                   1          1         Soda        77              7
# 5                   1          1         Soda        77              7
# 6                   2          1         Soda        77              7
# 7                   4          1         Soda        77              7
# 8                   1          1         Soda        77              7
# 9                   2          0         Soda        77              7
# 10                  6          1         Soda        77              7
# 11                  1          1         Soda        77              7
# 12                  1          1         Soda        77              7
# 13                  1          1         Soda        77              7
# 14                  3          0         Soda        77              7
#
#     prices        price_label     busiest_day    busiest_days  \
# 0      9.0  Mid-range product  Regularly busy      Least busy
# 1      9.0  Mid-range product  Regularly busy      Least busy
# 2      9.0  Mid-range product      Least busy      Least busy
# 3      9.0  Mid-range product      Least busy      Least busy
# 4      9.0  Mid-range product  Regularly busy  Regularly busy
# 5      9.0  Mid-range product  Regularly busy     Busiest day
# 6      9.0  Mid-range product  Regularly busy     Busiest day
# 7      9.0  Mid-range product  Regularly busy     Busiest day
# 8      9.0  Mid-range product      Least busy      Least busy
# 9      9.0  Mid-range product  Regularly busy     Busiest day
# 10     9.0  Mid-range product  Regularly busy  Regularly busy
# 11     9.0  Mid-range product  Regularly busy  Regularly busy
# 12     9.0  Mid-range product  Regularly busy     Busiest day
# 13     9.0  Mid-range product  Regularly busy     Busiest day
# 14     9.0  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1            Most orders         10
# 2         Average orders         10
# 3            Most orders         10
# 4         Average orders         10
# 5            Most orders         10
# 6            Most orders         10
# 7            Most orders         10
# 8         Average orders         10
# 9            Most orders         22
# 10           Most orders         22
# 11           Most orders         22
# 12           Most orders         22
# 13           Most orders         22
# 14           Most orders          9

# %% [markdown]
# We successfully created a new column that contains the max value for the "order_number" column, grouped by user_id.

# %%
# Checking more rows
df_ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  \
# 0    2398795        1             2                   3
# 1     473747        1             3                   3
# 2    2254736        1             4                   4
# 3     431534        1             5                   4
# 4    3367565        1             6                   2
# ..       ...      ...           ...                 ...
# 95   1548901      546             4                   3
# 96    668870      591             2                   1
# 97   2483801      626             2                   5
# 98   2741904      626             6                   1
# 99   2138689      626            10                   1
#
#     order_hour_of_creation  days_since_prior_order  product_id  \
# 0                        7                    15.0         196
# 1                       12                    21.0         196
# 2                        7                    29.0         196
# 3                       15                    28.0         196
# 4                        7                    19.0         196
# ..                     ...                     ...         ...
# 95                      18                    23.0         196
# 96                      13                     7.0         196
# 97                      15                     2.0         196
# 98                      14                     5.0         196
# 99                      10                     4.0         196
#
#     add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                   1          1         Soda        77              7
# 1                   1          1         Soda        77              7
# 2                   1          1         Soda        77              7
# 3                   1          1         Soda        77              7
# 4                   1          1         Soda        77              7
# ..                ...        ...          ...       ...            ...
# 95                  1          0         Soda        77              7
# 96                  1          0         Soda        77              7
# 97                 10          0         Soda        77              7
# 98                 12          1         Soda        77              7
# 99                  5          1         Soda        77              7
#
#     prices        price_label     busiest_day    busiest_days  \
# 0      9.0  Mid-range product  Regularly busy      Least busy
# 1      9.0  Mid-range product  Regularly busy      Least busy
# 2      9.0  Mid-range product      Least busy      Least busy
# 3      9.0  Mid-range product      Least busy      Least busy
# 4      9.0  Mid-range product  Regularly busy  Regularly busy
# ..     ...                ...             ...             ...
# 95     9.0  Mid-range product  Regularly busy      Least busy
# 96     9.0  Mid-range product  Regularly busy     Busiest day
# 97     9.0  Mid-range product  Regularly busy  Regularly busy
# 98     9.0  Mid-range product  Regularly busy     Busiest day
# 99     9.0  Mid-range product  Regularly busy     Busiest day
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1            Most orders         10
# 2         Average orders         10
# 3            Most orders         10
# 4         Average orders         10
# ..                   ...        ...
# 95        Average orders          6
# 96           Most orders          7
# 97           Most orders         94
# 98           Most orders         94
# 99           Most orders         94
#
# [100 rows x 18 columns]

# %% [markdown]
# It seems Jupyter is not showing all the requested rows (100) because of a default setting.

# %%
# Changing the setting, in order to see all rows requested.
pd.options.display.max_rows = None

# %%
# Testing again
df_ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  \
# 0    2398795        1             2                   3
# 1     473747        1             3                   3
# 2    2254736        1             4                   4
# 3     431534        1             5                   4
# 4    3367565        1             6                   2
# 5     550135        1             7                   1
# 6    3108588        1             8                   1
# 7    2295261        1             9                   1
# 8    2550362        1            10                   4
# 9    2968173       15            15                   1
# 10   1870022       15            17                   2
# 11   1911383       15            18                   2
# 12   2715276       15            21                   1
# 13    487368       15            22                   1
# 14   2293453       19             2                   5
# 15   1973799       19             5                   6
# 16    532817       19             7                   4
# 17   1573906       21            10                   3
# 18   1593000       31            10                   3
# 19   2231262       31            17                   3
# 20   2580647       43             6                   4
# 21   2187180       43             9                   4
# 22   1318871       52             2                   1
# 23   1261384       52             3                   1
# 24    580568       52             5                   2
# 25   2428073       52             7                   2
# 26    342306       52             9                   1
# 27   1520353       52            10                   2
# 28   2542086       52            11                   2
# 29    944694       52            12                   1
# 30   1268191       52            15                   2
# 31   1122089       52            17                   2
# 32   1498922       52            18                   2
# 33    180919       52            19                   3
# 34   2695875       52            21                   5
# 35    970922       67             2                   1
# 36    596585       67             3                   1
# 37   2037087       67             4                   2
# 38   2474111       67             5                   3
# 39   1568481       67             6                   3
# 40   2048527       67             8                   2
# 41   2389031       67             9                   2
# 42   2378562       67            10                   1
# 43   1515698       67            11                   1
# 44   1928050       67            12                   2
# 45   1949274       67            13                   1
# 46    551869       67            14                   1
# 47    768572       67            16                   4
# 48    150528       67            18                   5
# 49     29758       67            19                   0
# 50   1558976       67            21                   1
# 51    863974       67            22                   1
# 52   2308399       67            23                   1
# 53   2759128       81             3                   1
# 54   1812985       81             5                   2
# 55    499460       82             3                   5
# 56   2728456       82             4                   0
# 57   2653743       82             6                   4
# 58   1358880       82             9                   1
# 59    343588       82            10                   2
# 60   3034663       82            15                   2
# 61    147262       82            18                   1
# 62   3144004       82            19                   2
# 63   2126069       98             3                   0
# 64   2210120       98             7                   5
# 65    681011       98             9                   3
# 66   2846344       98            11                   4
# 67    747431       98            12                   6
# 68   2383054       98            13                   4
# 69   1993729       98            14                   5
# 70   1403849      109             3                   3
# 71   3273029      120             3                   2
# 72   1861943      185             2                   1
# 73   1680569      195             8                   1
# 74    276171      195            19                   5
# 75   2744976      195            22                   5
# 76   2781919      195            25                   1
# 77   1738718      195            31                   2
# 78   3058369      195            34                   3
# 79   1485596      195            37                   2
# 80    417035      195            40                   3
# 81   1615297      195            47                   5
# 82   1765587      195            52                   3
# 83    745908      195            57                   4
# 84   2505656      222            17                   2
# 85   3268370      222            38                   5
# 86   2016711      290             9                   5
# 87   2706088      290            28                   6
# 88   1952286      331             6                   5
# 89   1469869      377             3                   5
# 90   1927023      387             2                   4
# 91    858092      420             4                   1
# 92    119314      420             5                   3
# 93   1665683      423             3                   2
# 94   3096825      423            19                   2
# 95   1548901      546             4                   3
# 96    668870      591             2                   1
# 97   2483801      626             2                   5
# 98   2741904      626             6                   1
# 99   2138689      626            10                   1
#
#     order_hour_of_creation  days_since_prior_order  product_id  \
# 0                        7                    15.0         196
# 1                       12                    21.0         196
# 2                        7                    29.0         196
# 3                       15                    28.0         196
# 4                        7                    19.0         196
# 5                        9                    20.0         196
# 6                       14                    14.0         196
# 7                       16                     0.0         196
# 8                        8                    30.0         196
# 9                        9                     7.0         196
# 10                      16                     8.0         196
# 11                      11                     7.0         196
# 12                       9                     7.0         196
# 13                      10                    14.0         196
# 14                      14                     6.0         196
# 15                      12                     8.0         196
# 16                      17                     6.0         196
# 17                      10                     6.0         196
# 18                       8                     7.0         196
# 19                      11                     8.0         196
# 20                      16                     4.0         196
# 21                      12                     3.0         196
# 22                      10                     7.0         196
# 23                      10                     7.0         196
# 24                      10                     8.0         196
# 25                       7                     8.0         196
# 26                      11                     7.0         196
# 27                      10                     8.0         196
# 28                       9                     7.0         196
# 29                      16                     6.0         196
# 30                      11                     8.0         196
# 31                      10                     6.0         196
# 32                      10                    14.0         196
# 33                       8                     8.0         196
# 34                      10                    30.0         196
# 35                      15                     5.0         196
# 36                      13                     7.0         196
# 37                       9                     8.0         196
# 38                      14                     8.0         196
# 39                      12                     7.0         196
# 40                      11                     7.0         196
# 41                      14                     7.0         196
# 42                      10                     6.0         196
# 43                      11                     7.0         196
# 44                      12                     8.0         196
# 45                      10                     6.0         196
# 46                       9                     7.0         196
# 47                      10                     9.0         196
# 48                      16                     4.0         196
# 49                      14                     9.0         196
# 50                       9                     5.0         196
# 51                      11                    14.0         196
# 52                      14                    14.0         196
# 53                       9                    14.0         196
# 54                      20                    30.0         196
# 55                      10                     5.0         196
# 56                      11                    16.0         196
# 57                       9                    13.0         196
# 58                      10                    30.0         196
# 59                      11                     1.0         196
# 60                      11                    12.0         196
# 61                      13                     7.0         196
# 62                      15                     8.0         196
# 63                       9                    25.0         196
# 64                      14                     5.0         196
# 65                       9                    30.0         196
# 66                      13                    15.0         196
# 67                      13                    30.0         196
# 68                      11                    30.0         196
# 69                       8                     8.0         196
# 70                      17                     9.0         196
# 71                       8                    19.0         196
# 72                      12                    25.0         196
# 73                       9                     4.0         196
# 74                      11                     3.0         196
# 75                      10                     7.0         196
# 76                      14                     4.0         196
# 77                       8                     4.0         196
# 78                      10                     6.0         196
# 79                      15                     0.0         196
# 80                      16                     2.0         196
# 81                      10                     2.0         196
# 82                      12                     2.0         196
# 83                      11                     3.0         196
# 84                      12                     1.0         196
# 85                      15                     1.0         196
# 86                      19                     6.0         196
# 87                      10                     7.0         196
# 88                      16                    30.0         196
# 89                      17                     3.0         196
# 90                      10                    22.0         196
# 91                      19                    30.0         196
# 92                      19                    16.0         196
# 93                      11                     7.0         196
# 94                      11                     7.0         196
# 95                      18                    23.0         196
# 96                      13                     7.0         196
# 97                      15                     2.0         196
# 98                      14                     5.0         196
# 99                      10                     4.0         196
#
#     add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                   1          1         Soda        77              7
# 1                   1          1         Soda        77              7
# 2                   1          1         Soda        77              7
# 3                   1          1         Soda        77              7
# 4                   1          1         Soda        77              7
# 5                   1          1         Soda        77              7
# 6                   2          1         Soda        77              7
# 7                   4          1         Soda        77              7
# 8                   1          1         Soda        77              7
# 9                   2          0         Soda        77              7
# 10                  6          1         Soda        77              7
# 11                  1          1         Soda        77              7
# 12                  1          1         Soda        77              7
# 13                  1          1         Soda        77              7
# 14                  3          0         Soda        77              7
# 15                 15          1         Soda        77              7
# 16                  1          1         Soda        77              7
# 17                  2          0         Soda        77              7
# 18                 17          0         Soda        77              7
# 19                 14          1         Soda        77              7
# 20                  9          0         Soda        77              7
# 21                  1          1         Soda        77              7
# 22                  5          1         Soda        77              7
# 23                  3          1         Soda        77              7
# 24                  6          1         Soda        77              7
# 25                  5          1         Soda        77              7
# 26                  5          1         Soda        77              7
# 27                  4          1         Soda        77              7
# 28                  3          1         Soda        77              7
# 29                  7          1         Soda        77              7
# 30                  3          1         Soda        77              7
# 31                  4          1         Soda        77              7
# 32                  6          1         Soda        77              7
# 33                  4          1         Soda        77              7
# 34                  1          1         Soda        77              7
# 35                  2          1         Soda        77              7
# 36                  2          1         Soda        77              7
# 37                  1          1         Soda        77              7
# 38                  2          1         Soda        77              7
# 39                  2          1         Soda        77              7
# 40                  1          1         Soda        77              7
# 41                  1          1         Soda        77              7
# 42                  1          1         Soda        77              7
# 43                  1          1         Soda        77              7
# 44                  1          1         Soda        77              7
# 45                  1          1         Soda        77              7
# 46                  1          1         Soda        77              7
# 47                  1          1         Soda        77              7
# 48                  1          1         Soda        77              7
# 49                  2          1         Soda        77              7
# 50                  2          1         Soda        77              7
# 51                  3          1         Soda        77              7
# 52                  1          1         Soda        77              7
# 53                  2          0         Soda        77              7
# 54                  1          1         Soda        77              7
# 55                  2          1         Soda        77              7
# 56                  1          1         Soda        77              7
# 57                  5          1         Soda        77              7
# 58                  1          1         Soda        77              7
# 59                  1          1         Soda        77              7
# 60                  1          1         Soda        77              7
# 61                  1          1         Soda        77              7
# 62                  1          1         Soda        77              7
# 63                  7          0         Soda        77              7
# 64                  1          1         Soda        77              7
# 65                  1          1         Soda        77              7
# 66                  2          1         Soda        77              7
# 67                  4          1         Soda        77              7
# 68                  1          1         Soda        77              7
# 69                  2          1         Soda        77              7
# 70                  5          0         Soda        77              7
# 71                  2          1         Soda        77              7
# 72                 10          0         Soda        77              7
# 73                  2          1         Soda        77              7
# 74                  2          1         Soda        77              7
# 75                  2          1         Soda        77              7
# 76                  1          1         Soda        77              7
# 77                  2          1         Soda        77              7
# 78                  2          1         Soda        77              7
# 79                  2          1         Soda        77              7
# 80                  2          1         Soda        77              7
# 81                  2          1         Soda        77              7
# 82                  3          1         Soda        77              7
# 83                  3          1         Soda        77              7
# 84                  2          0         Soda        77              7
# 85                  6          1         Soda        77              7
# 86                  8          0         Soda        77              7
# 87                 16          1         Soda        77              7
# 88                  8          0         Soda        77              7
# 89                  9          0         Soda        77              7
# 90                  3          0         Soda        77              7
# 91                  2          0         Soda        77              7
# 92                  2          1         Soda        77              7
# 93                  3          0         Soda        77              7
# 94                  2          1         Soda        77              7
# 95                  1          0         Soda        77              7
# 96                  1          0         Soda        77              7
# 97                 10          0         Soda        77              7
# 98                 12          1         Soda        77              7
# 99                  5          1         Soda        77              7
#
#     prices        price_label     busiest_day    busiest_days  \
# 0      9.0  Mid-range product  Regularly busy      Least busy
# 1      9.0  Mid-range product  Regularly busy      Least busy
# 2      9.0  Mid-range product      Least busy      Least busy
# 3      9.0  Mid-range product      Least busy      Least busy
# 4      9.0  Mid-range product  Regularly busy  Regularly busy
# 5      9.0  Mid-range product  Regularly busy     Busiest day
# 6      9.0  Mid-range product  Regularly busy     Busiest day
# 7      9.0  Mid-range product  Regularly busy     Busiest day
# 8      9.0  Mid-range product      Least busy      Least busy
# 9      9.0  Mid-range product  Regularly busy     Busiest day
# 10     9.0  Mid-range product  Regularly busy  Regularly busy
# 11     9.0  Mid-range product  Regularly busy  Regularly busy
# 12     9.0  Mid-range product  Regularly busy     Busiest day
# 13     9.0  Mid-range product  Regularly busy     Busiest day
# 14     9.0  Mid-range product  Regularly busy  Regularly busy
# 15     9.0  Mid-range product  Regularly busy  Regularly busy
# 16     9.0  Mid-range product      Least busy      Least busy
# 17     9.0  Mid-range product  Regularly busy      Least busy
# 18     9.0  Mid-range product  Regularly busy      Least busy
# 19     9.0  Mid-range product  Regularly busy      Least busy
# 20     9.0  Mid-range product      Least busy      Least busy
# 21     9.0  Mid-range product      Least busy      Least busy
# 22     9.0  Mid-range product  Regularly busy     Busiest day
# 23     9.0  Mid-range product  Regularly busy     Busiest day
# 24     9.0  Mid-range product  Regularly busy  Regularly busy
# 25     9.0  Mid-range product  Regularly busy  Regularly busy
# 26     9.0  Mid-range product  Regularly busy     Busiest day
# 27     9.0  Mid-range product  Regularly busy  Regularly busy
# 28     9.0  Mid-range product  Regularly busy  Regularly busy
# 29     9.0  Mid-range product  Regularly busy     Busiest day
# 30     9.0  Mid-range product  Regularly busy  Regularly busy
# 31     9.0  Mid-range product  Regularly busy  Regularly busy
# 32     9.0  Mid-range product  Regularly busy  Regularly busy
# 33     9.0  Mid-range product  Regularly busy      Least busy
# 34     9.0  Mid-range product  Regularly busy  Regularly busy
# 35     9.0  Mid-range product  Regularly busy     Busiest day
# 36     9.0  Mid-range product  Regularly busy     Busiest day
# 37     9.0  Mid-range product  Regularly busy  Regularly busy
# 38     9.0  Mid-range product  Regularly busy      Least busy
# 39     9.0  Mid-range product  Regularly busy      Least busy
# 40     9.0  Mid-range product  Regularly busy  Regularly busy
# 41     9.0  Mid-range product  Regularly busy  Regularly busy
# 42     9.0  Mid-range product  Regularly busy     Busiest day
# 43     9.0  Mid-range product  Regularly busy     Busiest day
# 44     9.0  Mid-range product  Regularly busy  Regularly busy
# 45     9.0  Mid-range product  Regularly busy     Busiest day
# 46     9.0  Mid-range product  Regularly busy     Busiest day
# 47     9.0  Mid-range product      Least busy      Least busy
# 48     9.0  Mid-range product  Regularly busy  Regularly busy
# 49     9.0  Mid-range product     Busiest day     Busiest day
# 50     9.0  Mid-range product  Regularly busy     Busiest day
# 51     9.0  Mid-range product  Regularly busy     Busiest day
# 52     9.0  Mid-range product  Regularly busy     Busiest day
# 53     9.0  Mid-range product  Regularly busy     Busiest day
# 54     9.0  Mid-range product  Regularly busy  Regularly busy
# 55     9.0  Mid-range product  Regularly busy  Regularly busy
# 56     9.0  Mid-range product     Busiest day     Busiest day
# 57     9.0  Mid-range product      Least busy      Least busy
# 58     9.0  Mid-range product  Regularly busy     Busiest day
# 59     9.0  Mid-range product  Regularly busy  Regularly busy
# 60     9.0  Mid-range product  Regularly busy  Regularly busy
# 61     9.0  Mid-range product  Regularly busy     Busiest day
# 62     9.0  Mid-range product  Regularly busy  Regularly busy
# 63     9.0  Mid-range product     Busiest day     Busiest day
# 64     9.0  Mid-range product  Regularly busy  Regularly busy
# 65     9.0  Mid-range product  Regularly busy      Least busy
# 66     9.0  Mid-range product      Least busy      Least busy
# 67     9.0  Mid-range product  Regularly busy  Regularly busy
# 68     9.0  Mid-range product      Least busy      Least busy
# 69     9.0  Mid-range product  Regularly busy  Regularly busy
# 70     9.0  Mid-range product  Regularly busy      Least busy
# 71     9.0  Mid-range product  Regularly busy  Regularly busy
# 72     9.0  Mid-range product  Regularly busy     Busiest day
# 73     9.0  Mid-range product  Regularly busy     Busiest day
# 74     9.0  Mid-range product  Regularly busy  Regularly busy
# 75     9.0  Mid-range product  Regularly busy  Regularly busy
# 76     9.0  Mid-range product  Regularly busy     Busiest day
# 77     9.0  Mid-range product  Regularly busy  Regularly busy
# 78     9.0  Mid-range product  Regularly busy      Least busy
# 79     9.0  Mid-range product  Regularly busy  Regularly busy
# 80     9.0  Mid-range product  Regularly busy      Least busy
# 81     9.0  Mid-range product  Regularly busy  Regularly busy
# 82     9.0  Mid-range product  Regularly busy      Least busy
# 83     9.0  Mid-range product      Least busy      Least busy
# 84     9.0  Mid-range product  Regularly busy  Regularly busy
# 85     9.0  Mid-range product  Regularly busy  Regularly busy
# 86     9.0  Mid-range product  Regularly busy  Regularly busy
# 87     9.0  Mid-range product  Regularly busy  Regularly busy
# 88     9.0  Mid-range product  Regularly busy  Regularly busy
# 89     9.0  Mid-range product  Regularly busy  Regularly busy
# 90     9.0  Mid-range product      Least busy      Least busy
# 91     9.0  Mid-range product  Regularly busy     Busiest day
# 92     9.0  Mid-range product  Regularly busy      Least busy
# 93     9.0  Mid-range product  Regularly busy  Regularly busy
# 94     9.0  Mid-range product  Regularly busy  Regularly busy
# 95     9.0  Mid-range product  Regularly busy      Least busy
# 96     9.0  Mid-range product  Regularly busy     Busiest day
# 97     9.0  Mid-range product  Regularly busy  Regularly busy
# 98     9.0  Mid-range product  Regularly busy     Busiest day
# 99     9.0  Mid-range product  Regularly busy     Busiest day
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1            Most orders         10
# 2         Average orders         10
# 3            Most orders         10
# 4         Average orders         10
# 5            Most orders         10
# 6            Most orders         10
# 7            Most orders         10
# 8         Average orders         10
# 9            Most orders         22
# 10           Most orders         22
# 11           Most orders         22
# 12           Most orders         22
# 13           Most orders         22
# 14           Most orders          9
# 15           Most orders          9
# 16        Average orders          9
# 17           Most orders         33
# 18        Average orders         20
# 19           Most orders         20
# 20           Most orders         11
# 21           Most orders         11
# 22           Most orders         27
# 23           Most orders         27
# 24           Most orders         27
# 25        Average orders         27
# 26           Most orders         27
# 27           Most orders         27
# 28           Most orders         27
# 29           Most orders         27
# 30           Most orders         27
# 31           Most orders         27
# 32           Most orders         27
# 33        Average orders         27
# 34           Most orders         27
# 35           Most orders         24
# 36           Most orders         24
# 37           Most orders         24
# 38           Most orders         24
# 39           Most orders         24
# 40           Most orders         24
# 41           Most orders         24
# 42           Most orders         24
# 43           Most orders         24
# 44           Most orders         24
# 45           Most orders         24
# 46           Most orders         24
# 47           Most orders         24
# 48           Most orders         24
# 49           Most orders         24
# 50           Most orders         24
# 51           Most orders         24
# 52           Most orders         24
# 53           Most orders          7
# 54        Average orders          7
# 55           Most orders         19
# 56           Most orders         19
# 57           Most orders         19
# 58           Most orders         19
# 59           Most orders         19
# 60           Most orders         19
# 61           Most orders         19
# 62           Most orders         19
# 63           Most orders         14
# 64           Most orders         14
# 65           Most orders         14
# 66           Most orders         14
# 67           Most orders         14
# 68           Most orders         14
# 69        Average orders         14
# 70        Average orders          6
# 71        Average orders          3
# 72           Most orders          6
# 73           Most orders         58
# 74           Most orders         58
# 75           Most orders         58
# 76           Most orders         58
# 77        Average orders         58
# 78           Most orders         58
# 79           Most orders         58
# 80           Most orders         58
# 81           Most orders         58
# 82           Most orders         58
# 83           Most orders         58
# 84           Most orders         70
# 85           Most orders         70
# 86        Average orders         51
# 87           Most orders         51
# 88           Most orders          8
# 89        Average orders          3
# 90           Most orders          8
# 91        Average orders         22
# 92        Average orders         22
# 93           Most orders         42
# 94           Most orders         42
# 95        Average orders          6
# 96           Most orders          7
# 97           Most orders         94
# 98           Most orders         94
# 99           Most orders         94

# %% [markdown]
# That worked!

# %% [markdown]
# # 4. Creating a flag from the new aggregated column

# %% [markdown]
# Now that we have our new column containing the max order value for every user_id, we can use it to segmentate our customer into three different categories: Loyal, Regular or New. <br>
# If the max order value of a user is > 40, then that user is a "Loyal Customer". <br>
# If the max order value of a user is > 10 and <= 40, then that user is a "Regular Customer". <br>
# If the max order value of a user is <= 10, then that user is a "New Customer".

# %%
# Setting up the conditions for the new flag column
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] <= 40) & (df_ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking the head
df_ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
# 5    550135        1             7                   1
# 6   3108588        1             8                   1
# 7   2295261        1             9                   1
# 8   2550362        1            10                   4
# 9   2968173       15            15                   1
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
# 5                       9                    20.0         196
# 6                      14                    14.0         196
# 7                      16                     0.0         196
# 8                       8                    30.0         196
# 9                       9                     7.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          1         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
# 5                  1          1         Soda        77              7     9.0
# 6                  2          1         Soda        77              7     9.0
# 7                  4          1         Soda        77              7     9.0
# 8                  1          1         Soda        77              7     9.0
# 9                  2          0         Soda        77              7     9.0
#
#          price_label     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy      Least busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy           Most orders
# 2  Mid-range product      Least busy      Least busy        Average orders
# 3  Mid-range product      Least busy      Least busy           Most orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders
# 5  Mid-range product  Regularly busy     Busiest day           Most orders
# 6  Mid-range product  Regularly busy     Busiest day           Most orders
# 7  Mid-range product  Regularly busy     Busiest day           Most orders
# 8  Mid-range product      Least busy      Least busy        Average orders
# 9  Mid-range product  Regularly busy     Busiest day           Most orders
#
#    max_order      loyalty_flag
# 0         10      New customer
# 1         10      New customer
# 2         10      New customer
# 3         10      New customer
# 4         10      New customer
# 5         10      New customer
# 6         10      New customer
# 7         10      New customer
# 8         10      New customer
# 9         22  Regular customer

# %%
# Printing the frequency
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
# As a bonus, checking the head of the columns of interest
df_ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             2
# 1         1      New customer             3
# 2         1      New customer             4
# 3         1      New customer             5
# 4         1      New customer             6
# 5         1      New customer             7
# 6         1      New customer             8
# 7         1      New customer             9
# 8         1      New customer            10
# 9        15  Regular customer            15
# 10       15  Regular customer            17
# 11       15  Regular customer            18
# 12       15  Regular customer            21
# 13       15  Regular customer            22
# 14       19      New customer             2
# 15       19      New customer             5
# 16       19      New customer             7
# 17       21  Regular customer            10
# 18       31  Regular customer            10
# 19       31  Regular customer            17
# 20       43  Regular customer             6
# 21       43  Regular customer             9
# 22       52  Regular customer             2
# 23       52  Regular customer             3
# 24       52  Regular customer             5
# 25       52  Regular customer             7
# 26       52  Regular customer             9
# 27       52  Regular customer            10
# 28       52  Regular customer            11
# 29       52  Regular customer            12
# 30       52  Regular customer            15
# 31       52  Regular customer            17
# 32       52  Regular customer            18
# 33       52  Regular customer            19
# 34       52  Regular customer            21
# 35       67  Regular customer             2
# 36       67  Regular customer             3
# 37       67  Regular customer             4
# 38       67  Regular customer             5
# 39       67  Regular customer             6
# 40       67  Regular customer             8
# 41       67  Regular customer             9
# 42       67  Regular customer            10
# 43       67  Regular customer            11
# 44       67  Regular customer            12
# 45       67  Regular customer            13
# 46       67  Regular customer            14
# 47       67  Regular customer            16
# 48       67  Regular customer            18
# 49       67  Regular customer            19
# 50       67  Regular customer            21
# 51       67  Regular customer            22
# 52       67  Regular customer            23
# 53       81      New customer             3
# 54       81      New customer             5
# 55       82  Regular customer             3
# 56       82  Regular customer             4
# 57       82  Regular customer             6
# 58       82  Regular customer             9
# 59       82  Regular customer            10
