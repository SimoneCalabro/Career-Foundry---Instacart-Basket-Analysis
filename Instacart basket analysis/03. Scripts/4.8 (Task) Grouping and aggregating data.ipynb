# %% [markdown]
# # 4.8 (Task) Grouping and aggregating data
# ** **
# ## Table of contents:
#
# 1. Importing libraries <br>
# 2. Importing dataframe <br>
# 3. Tasks
#     - 3.1 How to group and aggregate data
#     - 3.2 Creating a loyalty flag
#         - 3.2.1 Performing an aggregation, grouping by the new flag created
#     - 3.3 Creating a spending flag
#     - 3.4 Creating an order frequency flag
# 4. Exporting dataframe with new aggregations and flags
#     - 4.1 Final checks before exporting
#     - 4.2 Exporting dataframe
# ** **

# %% [markdown]
# # 1. Importing libraries
# ** **

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing dataframe
# ** **

# %%
# Creating a path variabile for the folder
path = r'C:\Users\Simone\Desktop\Career Foundry\Esercizi modulo 5\Instacart basket analysis'

# %%
# Importing dataframe with the derived columns from Prepared Data
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# Checking the head
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          1         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
#
#          price_label     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy      Least busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy           Most orders
# 2  Mid-range product      Least busy      Least busy        Average orders
# 3  Mid-range product      Least busy      Least busy           Most orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders

# %% [markdown]
# # 3. Tasks
# ** **

# %% [markdown]
# ## 3.1 How to group and aggregate data

# %%
# Grouping data by department_id and aggregating by order_number (mean)
df_ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# <b> Observations: </b> <br>
# Compared to the operation performed on the subset (Script 4.8 - Exercise), this line of code is comprehensive of more elements. <br>
# In the subset there were only 8 department_ids, while here we can see all 21. <br>
# The order number mean for every department_id is similar, fluctuating between 16 to 18, with 3 exceptions. <br>
# In the subset, the mean fluctuated between 18 and 20, with an exception of 12, because of the subsetting.

# %% [markdown]
# ## 3.2 Creating a loyalty flag

# %% [markdown]
# To create a loyalty flag, we first of all need to create a new order containing the max value for order number, grouped by user id.

# %%
#Creating a new column containing the max value order number, with the data groupd by user id.
df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking the head
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  \
# 0    2398795        1             2                   3
# 1     473747        1             3                   3
# 2    2254736        1             4                   4
# 3     431534        1             5                   4
# 4    3367565        1             6                   2
# 5     550135        1             7                   1
# 6    3108588        1             8                   1
# 7    2295261        1             9                   1
# 8    2550362        1            10                   4
# 9    2968173       15            15                   1
# 10   1870022       15            17                   2
# 11   1911383       15            18                   2
# 12   2715276       15            21                   1
# 13    487368       15            22                   1
# 14   2293453       19             2                   5
#
#     order_hour_of_creation  days_since_prior_order  product_id  \
# 0                        7                    15.0         196
# 1                       12                    21.0         196
# 2                        7                    29.0         196
# 3                       15                    28.0         196
# 4                        7                    19.0         196
# 5                        9                    20.0         196
# 6                       14                    14.0         196
# 7                       16                     0.0         196
# 8                        8                    30.0         196
# 9                        9                     7.0         196
# 10                      16                     8.0         196
# 11                      11                     7.0         196
# 12                       9                     7.0         196
# 13                      10                    14.0         196
# 14                      14                     6.0         196
#
#     add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                   1          1         Soda        77              7
# 1                   1          1         Soda        77              7
# 2                   1          1         Soda        77              7
# 3                   1          1         Soda        77              7
# 4                   1          1         Soda        77              7
# 5                   1          1         Soda        77              7
# 6                   2          1         Soda        77              7
# 7                   4          1         Soda        77              7
# 8                   1          1         Soda        77              7
# 9                   2          0         Soda        77              7
# 10                  6          1         Soda        77              7
# 11                  1          1         Soda        77              7
# 12                  1          1         Soda        77              7
# 13                  1          1         Soda        77              7
# 14                  3          0         Soda        77              7
#
#     prices        price_label     busiest_day    busiest_days  \
# 0      9.0  Mid-range product  Regularly busy      Least busy
# 1      9.0  Mid-range product  Regularly busy      Least busy
# 2      9.0  Mid-range product      Least busy      Least busy
# 3      9.0  Mid-range product      Least busy      Least busy
# 4      9.0  Mid-range product  Regularly busy  Regularly busy
# 5      9.0  Mid-range product  Regularly busy     Busiest day
# 6      9.0  Mid-range product  Regularly busy     Busiest day
# 7      9.0  Mid-range product  Regularly busy     Busiest day
# 8      9.0  Mid-range product      Least busy      Least busy
# 9      9.0  Mid-range product  Regularly busy     Busiest day
# 10     9.0  Mid-range product  Regularly busy  Regularly busy
# 11     9.0  Mid-range product  Regularly busy  Regularly busy
# 12     9.0  Mid-range product  Regularly busy     Busiest day
# 13     9.0  Mid-range product  Regularly busy     Busiest day
# 14     9.0  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1            Most orders         10
# 2         Average orders         10
# 3            Most orders         10
# 4         Average orders         10
# 5            Most orders         10
# 6            Most orders         10
# 7            Most orders         10
# 8         Average orders         10
# 9            Most orders         22
# 10           Most orders         22
# 11           Most orders         22
# 12           Most orders         22
# 13           Most orders         22
# 14           Most orders          9

# %% [markdown]
# Now that we have our new column containing the max order value for every user_id, we can use it to segmentate our customer into three different categories: Loyal, Regular or New. <br>
# If the max order value of a user is > 40, then that user is a "Loyal Customer". <br>
# If the max order value of a user is > 10 and <= 40, then that user is a "Regular Customer". <br>
# If the max order value of a user is <= 10, then that user is a "New Customer".

# %%
# Setting up the conditions for the new flag column
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] <= 40) & (df_ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking the head
df_ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
# 5    550135        1             7                   1
# 6   3108588        1             8                   1
# 7   2295261        1             9                   1
# 8   2550362        1            10                   4
# 9   2968173       15            15                   1
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
# 5                       9                    20.0         196
# 6                      14                    14.0         196
# 7                      16                     0.0         196
# 8                       8                    30.0         196
# 9                       9                     7.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          1         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
# 5                  1          1         Soda        77              7     9.0
# 6                  2          1         Soda        77              7     9.0
# 7                  4          1         Soda        77              7     9.0
# 8                  1          1         Soda        77              7     9.0
# 9                  2          0         Soda        77              7     9.0
#
#          price_label     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy      Least busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy           Most orders
# 2  Mid-range product      Least busy      Least busy        Average orders
# 3  Mid-range product      Least busy      Least busy           Most orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders
# 5  Mid-range product  Regularly busy     Busiest day           Most orders
# 6  Mid-range product  Regularly busy     Busiest day           Most orders
# 7  Mid-range product  Regularly busy     Busiest day           Most orders
# 8  Mid-range product      Least busy      Least busy        Average orders
# 9  Mid-range product  Regularly busy     Busiest day           Most orders
#
#    max_order      loyalty_flag
# 0         10      New customer
# 1         10      New customer
# 2         10      New customer
# 3         10      New customer
# 4         10      New customer
# 5         10      New customer
# 6         10      New customer
# 7         10      New customer
# 8         10      New customer
# 9         22  Regular customer

# %%
# Printing the frequency
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### 3.2.1 Performing an aggregation, grouping by the new flag created

# %% [markdown]
# What if we perform an aggregation grouping by the new flag created, to check some descriptive statistics?

# %%
# Checking the descriptive statistics of the product prices, grouping by the flag just created
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.402162  1.0  99999.0
# New customer      13.396333  1.0  99999.0
# Regular customer  12.546842  1.0  99999.0

# %% [markdown]
# <b> Observations: </b> <br>
# Surprisingly, the mean is slightly higher for the Regular customers. <br>
# The min value is 1, while the max value in all categories is suspiciously 99999 dollars. <br>
# This sounds like a typo or a placeholder. However, the wrong price of this item is hiding the real true max value.

# %%
# Trying to identify the item
df_ords_prods_merged.loc[df_ords_prods_merged['prices']==99999.0]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 27127653    183964      873             3                   0
# 27127654   1851256      873             4                   6
# 27127655   2763293     1893             2                   4
# 27127656   2564805     1893             4                   1
# 27127657    420057     3339             2                   0
# ...            ...      ...           ...                 ...
# 27128304   2249946   204099            29                   0
# 27128305   2363282   204099            31                   0
# 27128306   3181945   204395            13                   3
# 27128307   2486215   205227             7                   3
# 27128308   2232716   205227            10                   0
#
#           order_hour_of_creation  days_since_prior_order  product_id  \
# 27127653                      10                     7.0       33664
# 27127654                      12                    13.0       33664
# 27127655                      16                    13.0       33664
# 27127656                      17                    30.0       33664
# 27127657                      11                    13.0       33664
# ...                          ...                     ...         ...
# 27128304                       8                     4.0       33664
# 27128305                       9                     2.0       33664
# 27128306                      15                     8.0       33664
# 27128307                      20                     4.0       33664
# 27128308                      11                     4.0       33664
#
#           add_to_cart_order  reordered           product_name  aisle_id  \
# 27127653                 11          0  2 % Reduced Fat  Milk        84
# 27127654                  8          1  2 % Reduced Fat  Milk        84
# 27127655                  6          1  2 % Reduced Fat  Milk        84
# 27127656                  3          1  2 % Reduced Fat  Milk        84
# 27127657                 29          1  2 % Reduced Fat  Milk        84
# ...                     ...        ...                    ...       ...
# 27128304                  1          0  2 % Reduced Fat  Milk        84
# 27128305                  1          1  2 % Reduced Fat  Milk        84
# 27128306                 25          0  2 % Reduced Fat  Milk        84
# 27128307                  8          0  2 % Reduced Fat  Milk        84
# 27128308                 23          1  2 % Reduced Fat  Milk        84
#
#           department_id   prices         price_label     busiest_day  \
# 27127653             16  99999.0  High-range product     Busiest day
# 27127654             16  99999.0  High-range product  Regularly busy
# 27127655             16  99999.0  High-range product      Least busy
# 27127656             16  99999.0  High-range product  Regularly busy
# 27127657             16  99999.0  High-range product     Busiest day
# ...                 ...      ...                 ...             ...
# 27128304             16  99999.0  High-range product     Busiest day
# 27128305             16  99999.0  High-range product     Busiest day
# 27128306             16  99999.0  High-range product  Regularly busy
# 27128307             16  99999.0  High-range product  Regularly busy
# 27128308             16  99999.0  High-range product     Busiest day
#
#             busiest_days busiest_period_of_day  max_order      loyalty_flag
# 27127653     Busiest day           Most orders          8      New customer
# 27127654  Regularly busy           Most orders          8      New customer
# 27127655      Least busy           Most orders          6      New customer
# 27127656     Busiest day        Average orders          6      New customer
# 27127657     Busiest day           Most orders          6      New customer
# ...                  ...                   ...        ...               ...
# 27128304     Busiest day        Average orders         39  Regular customer
# 27128305     Busiest day           Most orders         39  Regular customer
# 27128306      Least busy           Most orders         15  Regular customer
# 27128307      Least busy        Average orders         12  Regular customer
# 27128308     Busiest day           Most orders         12  Regular customer
#
# [656 rows x 19 columns]

# %% [markdown]
# <b> Observations: </b> <br>
# It seems the "2 % Reduced Fat Milk" is the item with the wrong price, and is appearing in 656 rows. <br>
# This issue will be addressed with client. <br>
# <b> NOTE: </b> The issue has been solved in script 4.9

# %% [markdown]
# ## 3.3 Creating a spending flag

# %% [markdown]
# Before creating a spending flag, first of all we need to derive a new column with an aggregation.

# %%
# Creating a new column with the average (mean) price, grouped by user_id
df_ords_prods_merged['avg_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Rounding average to 2 decimal places
df_ords_prods_merged['avg_price'] = df_ords_prods_merged['avg_price'].round(2)

# %%
# Checking the head
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  \
# 0    2398795        1             2                   3
# 1     473747        1             3                   3
# 2    2254736        1             4                   4
# 3     431534        1             5                   4
# 4    3367565        1             6                   2
# 5     550135        1             7                   1
# 6    3108588        1             8                   1
# 7    2295261        1             9                   1
# 8    2550362        1            10                   4
# 9    2968173       15            15                   1
# 10   1870022       15            17                   2
# 11   1911383       15            18                   2
# 12   2715276       15            21                   1
# 13    487368       15            22                   1
# 14   2293453       19             2                   5
#
#     order_hour_of_creation  days_since_prior_order  product_id  \
# 0                        7                    15.0         196
# 1                       12                    21.0         196
# 2                        7                    29.0         196
# 3                       15                    28.0         196
# 4                        7                    19.0         196
# 5                        9                    20.0         196
# 6                       14                    14.0         196
# 7                       16                     0.0         196
# 8                        8                    30.0         196
# 9                        9                     7.0         196
# 10                      16                     8.0         196
# 11                      11                     7.0         196
# 12                       9                     7.0         196
# 13                      10                    14.0         196
# 14                      14                     6.0         196
#
#     add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                   1          1         Soda        77              7
# 1                   1          1         Soda        77              7
# 2                   1          1         Soda        77              7
# 3                   1          1         Soda        77              7
# 4                   1          1         Soda        77              7
# 5                   1          1         Soda        77              7
# 6                   2          1         Soda        77              7
# 7                   4          1         Soda        77              7
# 8                   1          1         Soda        77              7
# 9                   2          0         Soda        77              7
# 10                  6          1         Soda        77              7
# 11                  1          1         Soda        77              7
# 12                  1          1         Soda        77              7
# 13                  1          1         Soda        77              7
# 14                  3          0         Soda        77              7
#
#     prices        price_label     busiest_day    busiest_days  \
# 0      9.0  Mid-range product  Regularly busy      Least busy
# 1      9.0  Mid-range product  Regularly busy      Least busy
# 2      9.0  Mid-range product      Least busy      Least busy
# 3      9.0  Mid-range product      Least busy      Least busy
# 4      9.0  Mid-range product  Regularly busy  Regularly busy
# 5      9.0  Mid-range product  Regularly busy     Busiest day
# 6      9.0  Mid-range product  Regularly busy     Busiest day
# 7      9.0  Mid-range product  Regularly busy     Busiest day
# 8      9.0  Mid-range product      Least busy      Least busy
# 9      9.0  Mid-range product  Regularly busy     Busiest day
# 10     9.0  Mid-range product  Regularly busy  Regularly busy
# 11     9.0  Mid-range product  Regularly busy  Regularly busy
# 12     9.0  Mid-range product  Regularly busy     Busiest day
# 13     9.0  Mid-range product  Regularly busy     Busiest day
# 14     9.0  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day  max_order      loyalty_flag  avg_price
# 0         Average orders         10      New customer       6.37
# 1            Most orders         10      New customer       6.37
# 2         Average orders         10      New customer       6.37
# 3            Most orders         10      New customer       6.37
# 4         Average orders         10      New customer       6.37
# 5            Most orders         10      New customer       6.37
# 6            Most orders         10      New customer       6.37
# 7            Most orders         10      New customer       6.37
# 8         Average orders         10      New customer       6.37
# 9            Most orders         22  Regular customer       3.99
# 10           Most orders         22  Regular customer       3.99
# 11           Most orders         22  Regular customer       3.99
# 12           Most orders         22  Regular customer       3.99
# 13           Most orders         22  Regular customer       3.99
# 14           Most orders          9      New customer       8.46

# %% [markdown]
# The new column "avg_price" has been successfully created.

# %% [markdown]
# Now we can create the flag using the .loc function, with the following conditions: <br>
# If the average price is >= 10, then the customer is an "High spender". <br>
# If the average price is < 10, then the customer is a "Low spender".

# %%
# Setting the conditions
df_ords_prods_merged.loc[df_ords_prods_merged['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Checking the head
df_ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
# 5    550135        1             7                   1
# 6   3108588        1             8                   1
# 7   2295261        1             9                   1
# 8   2550362        1            10                   4
# 9   2968173       15            15                   1
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
# 5                       9                    20.0         196
# 6                      14                    14.0         196
# 7                      16                     0.0         196
# 8                       8                    30.0         196
# 9                       9                     7.0         196
#
#    add_to_cart_order  reordered product_name  ...  department_id  prices  \
# 0                  1          1         Soda  ...              7     9.0
# 1                  1          1         Soda  ...              7     9.0
# 2                  1          1         Soda  ...              7     9.0
# 3                  1          1         Soda  ...              7     9.0
# 4                  1          1         Soda  ...              7     9.0
# 5                  1          1         Soda  ...              7     9.0
# 6                  2          1         Soda  ...              7     9.0
# 7                  4          1         Soda  ...              7     9.0
# 8                  1          1         Soda  ...              7     9.0
# 9                  2          0         Soda  ...              7     9.0
#
#          price_label     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy      Least busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy           Most orders
# 2  Mid-range product      Least busy      Least busy        Average orders
# 3  Mid-range product      Least busy      Least busy           Most orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders
# 5  Mid-range product  Regularly busy     Busiest day           Most orders
# 6  Mid-range product  Regularly busy     Busiest day           Most orders
# 7  Mid-range product  Regularly busy     Busiest day           Most orders
# 8  Mid-range product      Least busy      Least busy        Average orders
# 9  Mid-range product  Regularly busy     Busiest day           Most orders
#
#   max_order      loyalty_flag avg_price  spending_flag
# 0        10      New customer      6.37    Low spender
# 1        10      New customer      6.37    Low spender
# 2        10      New customer      6.37    Low spender
# 3        10      New customer      6.37    Low spender
# 4        10      New customer      6.37    Low spender
# 5        10      New customer      6.37    Low spender
# 6        10      New customer      6.37    Low spender
# 7        10      New customer      6.37    Low spender
# 8        10      New customer      6.37    Low spender
# 9        22  Regular customer      3.99    Low spender
#
# [10 rows x 21 columns]

# %%
# Printing the frequency of the column
df_ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     29729366
# High spender      599397
# Name: spending_flag, dtype: int64

# %% [markdown]
# <b> Observations: </b> <br>
# Only a relatively small part of customers are "High spenders".

# %%
# Checking the head of the columns of interest
df_ords_prods_merged[['user_id', 'spending_flag', 'avg_price']].head(40)
# Out:
#     user_id spending_flag  avg_price
# 0         1   Low spender       6.37
# 1         1   Low spender       6.37
# 2         1   Low spender       6.37
# 3         1   Low spender       6.37
# 4         1   Low spender       6.37
# 5         1   Low spender       6.37
# 6         1   Low spender       6.37
# 7         1   Low spender       6.37
# 8         1   Low spender       6.37
# 9        15   Low spender       3.99
# 10       15   Low spender       3.99
# 11       15   Low spender       3.99
# 12       15   Low spender       3.99
# 13       15   Low spender       3.99
# 14       19   Low spender       8.46
# 15       19   Low spender       8.46
# 16       19   Low spender       8.46
# 17       21   Low spender       6.99
# 18       31   Low spender       8.20
# 19       31   Low spender       8.20
# 20       43   Low spender       7.32
# 21       43   Low spender       7.32
# 22       52   Low spender       6.33
# 23       52   Low spender       6.33
# 24       52   Low spender       6.33
# 25       52   Low spender       6.33
# 26       52   Low spender       6.33
# 27       52   Low spender       6.33
# 28       52   Low spender       6.33
# 29       52   Low spender       6.33
# 30       52   Low spender       6.33
# 31       52   Low spender       6.33
# 32       52   Low spender       6.33
# 33       52   Low spender       6.33
# 34       52   Low spender       6.33
# 35       67   Low spender       7.64
# 36       67   Low spender       7.64
# 37       67   Low spender       7.64
# 38       67   Low spender       7.64
# 39       67   Low spender       7.64

# %% [markdown]
# ## 3.4 Creating an order frequency flag

# %% [markdown]
# Before creating an order frequency flag, first of all we need to derive a new column with an aggregation.

# %%
# Creating a new column, grouping by user_id and aggregating by the median of days_since_prior_order
df_ords_prods_merged['median_days_since_prior_order'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking the head
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  \
# 0    2398795        1             2                   3
# 1     473747        1             3                   3
# 2    2254736        1             4                   4
# 3     431534        1             5                   4
# 4    3367565        1             6                   2
# 5     550135        1             7                   1
# 6    3108588        1             8                   1
# 7    2295261        1             9                   1
# 8    2550362        1            10                   4
# 9    2968173       15            15                   1
# 10   1870022       15            17                   2
# 11   1911383       15            18                   2
# 12   2715276       15            21                   1
# 13    487368       15            22                   1
# 14   2293453       19             2                   5
#
#     order_hour_of_creation  days_since_prior_order  product_id  \
# 0                        7                    15.0         196
# 1                       12                    21.0         196
# 2                        7                    29.0         196
# 3                       15                    28.0         196
# 4                        7                    19.0         196
# 5                        9                    20.0         196
# 6                       14                    14.0         196
# 7                       16                     0.0         196
# 8                        8                    30.0         196
# 9                        9                     7.0         196
# 10                      16                     8.0         196
# 11                      11                     7.0         196
# 12                       9                     7.0         196
# 13                      10                    14.0         196
# 14                      14                     6.0         196
#
#     add_to_cart_order  reordered product_name  ...  prices        price_label  \
# 0                   1          1         Soda  ...     9.0  Mid-range product
# 1                   1          1         Soda  ...     9.0  Mid-range product
# 2                   1          1         Soda  ...     9.0  Mid-range product
# 3                   1          1         Soda  ...     9.0  Mid-range product
# 4                   1          1         Soda  ...     9.0  Mid-range product
# 5                   1          1         Soda  ...     9.0  Mid-range product
# 6                   2          1         Soda  ...     9.0  Mid-range product
# 7                   4          1         Soda  ...     9.0  Mid-range product
# 8                   1          1         Soda  ...     9.0  Mid-range product
# 9                   2          0         Soda  ...     9.0  Mid-range product
# 10                  6          1         Soda  ...     9.0  Mid-range product
# 11                  1          1         Soda  ...     9.0  Mid-range product
# 12                  1          1         Soda  ...     9.0  Mid-range product
# 13                  1          1         Soda  ...     9.0  Mid-range product
# 14                  3          0         Soda  ...     9.0  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy      Least busy        Average orders        10
# 1   Regularly busy      Least busy           Most orders        10
# 2       Least busy      Least busy        Average orders        10
# 3       Least busy      Least busy           Most orders        10
# 4   Regularly busy  Regularly busy        Average orders        10
# 5   Regularly busy     Busiest day           Most orders        10
# 6   Regularly busy     Busiest day           Most orders        10
# 7   Regularly busy     Busiest day           Most orders        10
# 8       Least busy      Least busy        Average orders        10
# 9   Regularly busy     Busiest day           Most orders        22
# 10  Regularly busy  Regularly busy           Most orders        22
# 11  Regularly busy  Regularly busy           Most orders        22
# 12  Regularly busy     Busiest day           Most orders        22
# 13  Regularly busy     Busiest day           Most orders        22
# 14  Regularly busy  Regularly busy           Most orders         9
#
#         loyalty_flag  avg_price spending_flag  median_days_since_prior_order
# 0       New customer       6.37   Low spender                           20.5
# 1       New customer       6.37   Low spender                           20.5
# 2       New customer       6.37   Low spender                           20.5
# 3       New customer       6.37   Low spender                           20.5
# 4       New customer       6.37   Low spender                           20.5
# 5       New customer       6.37   Low spender                           20.5
# 6       New customer       6.37   Low spender                           20.5
# 7       New customer       6.37   Low spender                           20.5
# 8       New customer       6.37   Low spender                           20.5
# 9   Regular customer       3.99   Low spender                           10.0
# 10  Regular customer       3.99   Low spender                           10.0
# 11  Regular customer       3.99   Low spender                           10.0
# 12  Regular customer       3.99   Low spender                           10.0
# 13  Regular customer       3.99   Low spender                           10.0
# 14      New customer       8.46   Low spender                            6.0
#
# [15 rows x 22 columns]

# %% [markdown]
# The new column, "median_days_since_prior_order" has been successfully created.

# %% [markdown]
# Now we can create the flag using the .loc function, with the following conditions: <br>
# If the median days since prior order are > 20, then the customer is a "Non-frequent customer". <br>
# If the median days since prior order are > 10 and <= 20, then the customer is a "Regular customer". <br>
# If the median days since prior order are <= 10, then the customer is a "Frequent customer".

# %%
# Setting the conditions
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['median_days_since_prior_order'] > 10) & (df_ords_prods_merged['median_days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Checking the head
df_ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
# 5    550135        1             7                   1
# 6   3108588        1             8                   1
# 7   2295261        1             9                   1
# 8   2550362        1            10                   4
# 9   2968173       15            15                   1
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
# 5                       9                    20.0         196
# 6                      14                    14.0         196
# 7                      16                     0.0         196
# 8                       8                    30.0         196
# 9                       9                     7.0         196
#
#    add_to_cart_order  reordered product_name  ...        price_label  \
# 0                  1          1         Soda  ...  Mid-range product
# 1                  1          1         Soda  ...  Mid-range product
# 2                  1          1         Soda  ...  Mid-range product
# 3                  1          1         Soda  ...  Mid-range product
# 4                  1          1         Soda  ...  Mid-range product
# 5                  1          1         Soda  ...  Mid-range product
# 6                  2          1         Soda  ...  Mid-range product
# 7                  4          1         Soda  ...  Mid-range product
# 8                  1          1         Soda  ...  Mid-range product
# 9                  2          0         Soda  ...  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy      Least busy        Average orders        10
# 1  Regularly busy      Least busy           Most orders        10
# 2      Least busy      Least busy        Average orders        10
# 3      Least busy      Least busy           Most orders        10
# 4  Regularly busy  Regularly busy        Average orders        10
# 5  Regularly busy     Busiest day           Most orders        10
# 6  Regularly busy     Busiest day           Most orders        10
# 7  Regularly busy     Busiest day           Most orders        10
# 8      Least busy      Least busy        Average orders        10
# 9  Regularly busy     Busiest day           Most orders        22
#
#        loyalty_flag avg_price  spending_flag median_days_since_prior_order  \
# 0      New customer      6.37    Low spender                          20.5
# 1      New customer      6.37    Low spender                          20.5
# 2      New customer      6.37    Low spender                          20.5
# 3      New customer      6.37    Low spender                          20.5
# 4      New customer      6.37    Low spender                          20.5
# 5      New customer      6.37    Low spender                          20.5
# 6      New customer      6.37    Low spender                          20.5
# 7      New customer      6.37    Low spender                          20.5
# 8      New customer      6.37    Low spender                          20.5
# 9  Regular customer      3.99    Low spender                          10.0
#
#     order_frequency_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer
# 5  Non-frequent customer
# 6  Non-frequent customer
# 7  Non-frequent customer
# 8  Non-frequent customer
# 9      Frequent customer
#
# [10 rows x 23 columns]

# %%
# Printing the frequency of the new column
df_ords_prods_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# <b> Observations: </b> <br>
# The majority of Instacart customers are "Frequent", but there is also a consistent part of them that are "Regular".

# %%
# Checking the head of the columns of interest
df_ords_prods_merged[['user_id', 'order_frequency_flag', 'median_days_since_prior_order']].head(40)
# Out:
#     user_id   order_frequency_flag  median_days_since_prior_order
# 0         1  Non-frequent customer                           20.5
# 1         1  Non-frequent customer                           20.5
# 2         1  Non-frequent customer                           20.5
# 3         1  Non-frequent customer                           20.5
# 4         1  Non-frequent customer                           20.5
# 5         1  Non-frequent customer                           20.5
# 6         1  Non-frequent customer                           20.5
# 7         1  Non-frequent customer                           20.5
# 8         1  Non-frequent customer                           20.5
# 9        15      Frequent customer                           10.0
# 10       15      Frequent customer                           10.0
# 11       15      Frequent customer                           10.0
# 12       15      Frequent customer                           10.0
# 13       15      Frequent customer                           10.0
# 14       19      Frequent customer                            6.0
# 15       19      Frequent customer                            6.0
# 16       19      Frequent customer                            6.0
# 17       21      Frequent customer                            7.5
# 18       31      Frequent customer                            6.0
# 19       31      Frequent customer                            6.0
# 20       43      Frequent customer                           10.0
# 21       43      Frequent customer                           10.0
# 22       52      Frequent customer                            8.0
# 23       52      Frequent customer                            8.0
# 24       52      Frequent customer                            8.0
# 25       52      Frequent customer                            8.0
# 26       52      Frequent customer                            8.0
# 27       52      Frequent customer                            8.0
# 28       52      Frequent customer                            8.0
# 29       52      Frequent customer                            8.0
# 30       52      Frequent customer                            8.0
# 31       52      Frequent customer                            8.0
# 32       52      Frequent customer                            8.0
# 33       52      Frequent customer                            8.0
# 34       52      Frequent customer                            8.0
# 35       67      Frequent customer                            7.0
# 36       67      Frequent customer                            7.0
# 37       67      Frequent customer                            7.0
# 38       67      Frequent customer                            7.0
# 39       67      Frequent customer                            7.0

# %% [markdown]
# # 4. Exporting dataframe with new aggregations and flags
# ** **

# %% [markdown]
# ## 4.1 Final checks before exporting

# %%
# Checking the index, looking at the head and tail of the dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2398795        1             2                   3
# 1    473747        1             3                   3
# 2   2254736        1             4                   4
# 3    431534        1             5                   4
# 4   3367565        1             6                   2
#
#    order_hour_of_creation  days_since_prior_order  product_id  \
# 0                       7                    15.0         196
# 1                      12                    21.0         196
# 2                       7                    29.0         196
# 3                      15                    28.0         196
# 4                       7                    19.0         196
#
#    add_to_cart_order  reordered product_name  ...        price_label  \
# 0                  1          1         Soda  ...  Mid-range product
# 1                  1          1         Soda  ...  Mid-range product
# 2                  1          1         Soda  ...  Mid-range product
# 3                  1          1         Soda  ...  Mid-range product
# 4                  1          1         Soda  ...  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy      Least busy        Average orders        10
# 1  Regularly busy      Least busy           Most orders        10
# 2      Least busy      Least busy        Average orders        10
# 3      Least busy      Least busy           Most orders        10
# 4  Regularly busy  Regularly busy        Average orders        10
#
#    loyalty_flag avg_price  spending_flag median_days_since_prior_order  \
# 0  New customer      6.37    Low spender                          20.5
# 1  New customer      6.37    Low spender                          20.5
# 2  New customer      6.37    Low spender                          20.5
# 3  New customer      6.37    Low spender                          20.5
# 4  New customer      6.37    Low spender                          20.5
#
#     order_frequency_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer
#
# [5 rows x 23 columns]

# %%
df_ords_prods_merged.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 30328758     31526   202557            18                   5
# 30328759   2745165   203436             2                   3
# 30328760    850996   204229            12                   2
# 30328761   2550789   204472             6                   3
# 30328762   2518919   204641            10                   2
#
#           order_hour_of_creation  days_since_prior_order  product_id  \
# 30328758                      11                     3.0       43553
# 30328759                       5                    15.0       42338
# 30328760                       3                    25.0       37595
# 30328761                      15                     7.0       37595
# 30328762                      21                    11.0       20543
#
#           add_to_cart_order  reordered  \
# 30328758                  2          1
# 30328759                 16          1
# 30328760                 20          0
# 30328761                  9          0
# 30328762                 16          0
#
#                                              product_name  ...  \
# 30328758                              Orange Energy Shots  ...
# 30328759                            Zucchini Chips, Pesto  ...
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap  ...
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap  ...
# 30328762                                    Soleil Razors  ...
#
#                 price_label     busiest_day    busiest_days  \
# 30328758  Low-range product  Regularly busy  Regularly busy
# 30328759  Mid-range product  Regularly busy      Least busy
# 30328760  Mid-range product  Regularly busy  Regularly busy
# 30328761  Mid-range product  Regularly busy      Least busy
# 30328762  Mid-range product  Regularly busy  Regularly busy
#
#          busiest_period_of_day max_order      loyalty_flag avg_price  \
# 30328758           Most orders        31  Regular customer      6.91
# 30328759         Fewest orders         3      New customer      7.50
# 30328760         Fewest orders        22  Regular customer      7.95
# 30328761           Most orders        11  Regular customer      7.97
# 30328762        Average orders        35  Regular customer     44.59
#
#           spending_flag median_days_since_prior_order   order_frequency_flag
# 30328758    Low spender                           8.0      Frequent customer
# 30328759    Low spender                          15.0       Regular customer
# 30328760    Low spender                          16.0       Regular customer
# 30328761    Low spender                          30.0  Non-frequent customer
# 30328762   High spender                          11.0       Regular customer
#
# [5 rows x 23 columns]

# %% [markdown]
# Index is okay.

# %%
# Checking datatypes
df_ords_prods_merged.dtypes
# Out:
# order_id                           int64
# user_id                            int64
# order_number                       int64
# orders_day_of_week                 int64
# order_hour_of_creation             int64
# days_since_prior_order           float64
# product_id                         int64
# add_to_cart_order                  int64
# reordered                          int64
# product_name                      object
# aisle_id                           int64
# department_id                      int64
# prices                           float64
# price_label                       object
# busiest_day                       object
# busiest_days                      object
# busiest_period_of_day             object
# max_order                          int64
# loyalty_flag                      object
# avg_price                        float64
# spending_flag                     object
# median_days_since_prior_order    float64
# order_frequency_flag              object
# dtype: object

# %% [markdown]
# All the columns containing IDs and order number, should be strings.

# %%
# Changing the datatypes of multiple columns.
df_ords_prods_merged['order_id'] = df_ords_prods_merged['order_id'].astype('str')

# %%
df_ords_prods_merged['user_id'] = df_ords_prods_merged['user_id'].astype('str')

# %%
df_ords_prods_merged['order_number'] = df_ords_prods_merged['order_number'].astype('str')

# %%
df_ords_prods_merged['product_id'] = df_ords_prods_merged['product_id'].astype('str')

# %%
df_ords_prods_merged['aisle_id'] = df_ords_prods_merged['aisle_id'].astype('str')

# %%
df_ords_prods_merged['department_id'] = df_ords_prods_merged['department_id'].astype('str')

# %%
# Checking again datatypes
df_ords_prods_merged.dtypes
# Out:
# order_id                          object
# user_id                           object
# order_number                      object
# orders_day_of_week                 int64
# order_hour_of_creation             int64
# days_since_prior_order           float64
# product_id                        object
# add_to_cart_order                  int64
# reordered                          int64
# product_name                      object
# aisle_id                          object
# department_id                     object
# prices                           float64
# price_label                       object
# busiest_day                       object
# busiest_days                      object
# busiest_period_of_day             object
# max_order                          int64
# loyalty_flag                      object
# avg_price                        float64
# spending_flag                     object
# median_days_since_prior_order    float64
# order_frequency_flag              object
# dtype: object

# %% [markdown]
# Datatype have been changed.

# %%
# Final checks
df_ords_prods_merged
# Out:
#          order_id user_id order_number  orders_day_of_week  \
# 0         2398795       1            2                   3
# 1          473747       1            3                   3
# 2         2254736       1            4                   4
# 3          431534       1            5                   4
# 4         3367565       1            6                   2
# ...           ...     ...          ...                 ...
# 30328758    31526  202557           18                   5
# 30328759  2745165  203436            2                   3
# 30328760   850996  204229           12                   2
# 30328761  2550789  204472            6                   3
# 30328762  2518919  204641           10                   2
#
#           order_hour_of_creation  days_since_prior_order product_id  \
# 0                              7                    15.0        196
# 1                             12                    21.0        196
# 2                              7                    29.0        196
# 3                             15                    28.0        196
# 4                              7                    19.0        196
# ...                          ...                     ...        ...
# 30328758                      11                     3.0      43553
# 30328759                       5                    15.0      42338
# 30328760                       3                    25.0      37595
# 30328761                      15                     7.0      37595
# 30328762                      21                    11.0      20543
#
#           add_to_cart_order  reordered  \
# 0                         1          1
# 1                         1          1
# 2                         1          1
# 3                         1          1
# 4                         1          1
# ...                     ...        ...
# 30328758                  2          1
# 30328759                 16          1
# 30328760                 20          0
# 30328761                  9          0
# 30328762                 16          0
#
#                                              product_name  ...  \
# 0                                                    Soda  ...
# 1                                                    Soda  ...
# 2                                                    Soda  ...
# 3                                                    Soda  ...
# 4                                                    Soda  ...
# ...                                                   ...  ...
# 30328758                              Orange Energy Shots  ...
# 30328759                            Zucchini Chips, Pesto  ...
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap  ...
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap  ...
# 30328762                                    Soleil Razors  ...
#
#                 price_label     busiest_day    busiest_days  \
# 0         Mid-range product  Regularly busy      Least busy
# 1         Mid-range product  Regularly busy      Least busy
# 2         Mid-range product      Least busy      Least busy
# 3         Mid-range product      Least busy      Least busy
# 4         Mid-range product  Regularly busy  Regularly busy
# ...                     ...             ...             ...
# 30328758  Low-range product  Regularly busy  Regularly busy
# 30328759  Mid-range product  Regularly busy      Least busy
# 30328760  Mid-range product  Regularly busy  Regularly busy
# 30328761  Mid-range product  Regularly busy      Least busy
# 30328762  Mid-range product  Regularly busy  Regularly busy
#
#          busiest_period_of_day max_order      loyalty_flag avg_price  \
# 0               Average orders        10      New customer      6.37
# 1                  Most orders        10      New customer      6.37
# 2               Average orders        10      New customer      6.37
# 3                  Most orders        10      New customer      6.37
# 4               Average orders        10      New customer      6.37
# ...                        ...       ...               ...       ...
# 30328758           Most orders        31  Regular customer      6.91
# 30328759         Fewest orders         3      New customer      7.50
# 30328760         Fewest orders        22  Regular customer      7.95
# 30328761           Most orders        11  Regular customer      7.97
# 30328762        Average orders        35  Regular customer     44.59
#
#           spending_flag median_days_since_prior_order   order_frequency_flag
# 0           Low spender                          20.5  Non-frequent customer
# 1           Low spender                          20.5  Non-frequent customer
# 2           Low spender                          20.5  Non-frequent customer
# 3           Low spender                          20.5  Non-frequent customer
# 4           Low spender                          20.5  Non-frequent customer
# ...                 ...                           ...                    ...
# 30328758    Low spender                           8.0      Frequent customer
# 30328759    Low spender                          15.0       Regular customer
# 30328760    Low spender                          16.0       Regular customer
# 30328761    Low spender                          30.0  Non-frequent customer
# 30328762   High spender                          11.0       Regular customer
#
# [30328763 rows x 23 columns]

# %%
df_ords_prods_merged.head(10)
# Out:
#   order_id user_id order_number  orders_day_of_week  order_hour_of_creation  \
# 0  2398795       1            2                   3                       7
# 1   473747       1            3                   3                      12
# 2  2254736       1            4                   4                       7
# 3   431534       1            5                   4                      15
# 4  3367565       1            6                   2                       7
# 5   550135       1            7                   1                       9
# 6  3108588       1            8                   1                      14
# 7  2295261       1            9                   1                      16
# 8  2550362       1           10                   4                       8
# 9  2968173      15           15                   1                       9
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    15.0        196                  1          1
# 1                    21.0        196                  1          1
# 2                    29.0        196                  1          1
# 3                    28.0        196                  1          1
# 4                    19.0        196                  1          1
# 5                    20.0        196                  1          1
# 6                    14.0        196                  2          1
# 7                     0.0        196                  4          1
# 8                    30.0        196                  1          1
# 9                     7.0        196                  2          0
#
#   product_name  ...        price_label     busiest_day    busiest_days  \
# 0         Soda  ...  Mid-range product  Regularly busy      Least busy
# 1         Soda  ...  Mid-range product  Regularly busy      Least busy
# 2         Soda  ...  Mid-range product      Least busy      Least busy
# 3         Soda  ...  Mid-range product      Least busy      Least busy
# 4         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 5         Soda  ...  Mid-range product  Regularly busy     Busiest day
# 6         Soda  ...  Mid-range product  Regularly busy     Busiest day
# 7         Soda  ...  Mid-range product  Regularly busy     Busiest day
# 8         Soda  ...  Mid-range product      Least busy      Least busy
# 9         Soda  ...  Mid-range product  Regularly busy     Busiest day
#
#   busiest_period_of_day max_order      loyalty_flag avg_price  spending_flag  \
# 0        Average orders        10      New customer      6.37    Low spender
# 1           Most orders        10      New customer      6.37    Low spender
# 2        Average orders        10      New customer      6.37    Low spender
# 3           Most orders        10      New customer      6.37    Low spender
# 4        Average orders        10      New customer      6.37    Low spender
# 5           Most orders        10      New customer      6.37    Low spender
# 6           Most orders        10      New customer      6.37    Low spender
# 7           Most orders        10      New customer      6.37    Low spender
# 8        Average orders        10      New customer      6.37    Low spender
# 9           Most orders        22  Regular customer      3.99    Low spender
#
#   median_days_since_prior_order   order_frequency_flag
# 0                          20.5  Non-frequent customer
# 1                          20.5  Non-frequent customer
# 2                          20.5  Non-frequent customer
# 3                          20.5  Non-frequent customer
# 4                          20.5  Non-frequent customer
# 5                          20.5  Non-frequent customer
# 6                          20.5  Non-frequent customer
# 7                          20.5  Non-frequent customer
# 8                          20.5  Non-frequent customer
# 9                          10.0      Frequent customer
#
# [10 rows x 23 columns]

# %%
df_ords_prods_merged.tail(10)
# Out:
#          order_id user_id order_number  orders_day_of_week  \
# 30328753   960088  202557           13                   4
# 30328754   343962  202557           14                   0
# 30328755  2329472  202557           15                   6
# 30328756   694731  202557           16                   1
# 30328757  1320836  202557           17                   2
# 30328758    31526  202557           18                   5
# 30328759  2745165  203436            2                   3
# 30328760   850996  204229           12                   2
# 30328761  2550789  204472            6                   3
# 30328762  2518919  204641           10                   2
#
#           order_hour_of_creation  days_since_prior_order product_id  \
# 30328753                      12                    15.0      43553
# 30328754                      10                     3.0      43553
# 30328755                      12                     6.0      43553
# 30328756                      14                     2.0      43553
# 30328757                      15                     1.0      43553
# 30328758                      11                     3.0      43553
# 30328759                       5                    15.0      42338
# 30328760                       3                    25.0      37595
# 30328761                      15                     7.0      37595
# 30328762                      21                    11.0      20543
#
#           add_to_cart_order  reordered  \
# 30328753                  3          1
# 30328754                  2          1
# 30328755                  2          1
# 30328756                  2          1
# 30328757                  2          1
# 30328758                  2          1
# 30328759                 16          1
# 30328760                 20          0
# 30328761                  9          0
# 30328762                 16          0
#
#                                              product_name  ...  \
# 30328753                              Orange Energy Shots  ...
# 30328754                              Orange Energy Shots  ...
# 30328755                              Orange Energy Shots  ...
# 30328756                              Orange Energy Shots  ...
# 30328757                              Orange Energy Shots  ...
# 30328758                              Orange Energy Shots  ...
# 30328759                            Zucchini Chips, Pesto  ...
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap  ...
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap  ...
# 30328762                                    Soleil Razors  ...
#
#                 price_label     busiest_day    busiest_days  \
# 30328753  Low-range product      Least busy      Least busy
# 30328754  Low-range product     Busiest day     Busiest day
# 30328755  Low-range product  Regularly busy  Regularly busy
# 30328756  Low-range product  Regularly busy     Busiest day
# 30328757  Low-range product  Regularly busy  Regularly busy
# 30328758  Low-range product  Regularly busy  Regularly busy
# 30328759  Mid-range product  Regularly busy      Least busy
# 30328760  Mid-range product  Regularly busy  Regularly busy
# 30328761  Mid-range product  Regularly busy      Least busy
# 30328762  Mid-range product  Regularly busy  Regularly busy
#
#          busiest_period_of_day max_order      loyalty_flag avg_price  \
# 30328753           Most orders        31  Regular customer      6.91
# 30328754           Most orders        31  Regular customer      6.91
# 30328755           Most orders        31  Regular customer      6.91
# 30328756           Most orders        31  Regular customer      6.91
# 30328757           Most orders        31  Regular customer      6.91
# 30328758           Most orders        31  Regular customer      6.91
# 30328759         Fewest orders         3      New customer      7.50
# 30328760         Fewest orders        22  Regular customer      7.95
# 30328761           Most orders        11  Regular customer      7.97
# 30328762        Average orders        35  Regular customer     44.59
#
#           spending_flag median_days_since_prior_order   order_frequency_flag
# 30328753    Low spender                           8.0      Frequent customer
# 30328754    Low spender                           8.0      Frequent customer
# 30328755    Low spender                           8.0      Frequent customer
# 30328756    Low spender                           8.0      Frequent customer
# 30328757    Low spender                           8.0      Frequent customer
# 30328758    Low spender                           8.0      Frequent customer
# 30328759    Low spender                          15.0       Regular customer
# 30328760    Low spender                          16.0       Regular customer
# 30328761    Low spender                          30.0  Non-frequent customer
# 30328762   High spender                          11.0       Regular customer
#
# [10 rows x 23 columns]

# %% [markdown]
# ## 4.2 Exporting dataframe

# %%
# Exporting the dataframe as a pickle file
df_ords_prods_merged.to_pickle(os.path.join(path, '02. Data','Prepared Data', 'orders_products_merged_derived_flags.pkl'))
